# %% [markdown]
# <a href="https://colab.research.google.com/github/Joocheol/joocheol.github.io/blob/master/20200928_Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Usual imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#@title Male vs. Female heights { vertical-output: true }
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("https://github.com/Joocheol/Financial-Engineering/blob/master/galton.csv?raw=True")

height_m = df[df['gender']=='M']['height']
height_f = df[df['gender']=='F']['height']

plt.hist(height_m, bins=15, alpha=0.5)
plt.hist(height_f, bins=15, alpha=0.5)
plt.grid(True)
plt.show()

# %%
df
# Out:
#      family  father  mother gender  height  kids  male  female
# 0         1    78.5    67.0      M    73.2     4     1       0
# 1         1    78.5    67.0      F    69.2     4     0       1
# 2         1    78.5    67.0      F    69.0     4     0       1
# 3         1    78.5    67.0      F    69.0     4     0       1
# 4         2    75.5    66.5      M    73.5     4     1       0
# ..      ...     ...     ...    ...     ...   ...   ...     ...
# 885     203    62.0    66.0      M    64.0     3     1       0
# 886     203    62.0    66.0      F    62.0     3     0       1
# 887     203    62.0    66.0      F    61.0     3     0       1
# 888     204    62.5    63.0      M    66.5     2     1       0
# 889     204    62.5    63.0      F    57.0     2     0       1
#
# [890 rows x 8 columns]

# %%
height_m
# Out:
# 0      73.2
# 4      73.5
# 5      72.5
# 8      71.0
# 10     70.5
#        ...
# 876    68.0
# 882    64.5
# 883    66.0
# 885    64.0
# 888    66.5
# Name: height, Length: 460, dtype: float64

# %%
x = df['height']

# %%
x
# Out:
# 0      73.2
# 1      69.2
# 2      69.0
# 3      69.0
# 4      73.5
#        ...
# 885    64.0
# 886    62.0
# 887    61.0
# 888    66.5
# 889    57.0
# Name: height, Length: 890, dtype: float64

# %%
y = df['male']

# %%
y
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 885    1
# 886    0
# 887    0
# 888    1
# 889    0
# Name: male, Length: 890, dtype: int64

# %%
w = 1.0
b = 1.0

# %%
my_model = w*x + b

# %%
my_model
# Out:
# 0      74.2
# 1      70.2
# 2      70.0
# 3      70.0
# 4      74.5
#        ...
# 885    65.0
# 886    63.0
# 887    62.0
# 888    67.5
# 889    58.0
# Name: height, Length: 890, dtype: float64

# %%
(my_model - y)**2
# Out:
# 0      5358.24
# 1      4928.04
# 2      4900.00
# 3      4900.00
# 4      5402.25
#         ...
# 885    4096.00
# 886    3969.00
# 887    3844.00
# 888    4422.25
# 889    3364.00
# Length: 890, dtype: float64

# %%
np.mean((my_model - y)**2)
# Out:
# 4531.700629213484

# %%
mse = [[w, b, np.mean((w*x + b - y)**2)] for w in np.arange(-10, 10, 0.1) for b in np.arange(-10, 10, 1)]

# %%
np_mse = np.array(mse)

# %%
np_mse.shape
# Out:
# (4000, 3)

# %%
np_mse[:, 2].min()
# Out:
# 0.1481029213475531

# %%
np.argmin(np_mse[:, 2], axis=0)
# Out:
# 2024

# %%
np_mse[2024]
# Out:
# array([ 0.1       , -6.        ,  0.14810292])

# %%
plt.scatter(x, y)
plt.show()

# %%
plt.scatter(x, y)
plt.plot(x, 0.1*x-6)
plt.ylim([-0.05, 1.05])
plt.show()
